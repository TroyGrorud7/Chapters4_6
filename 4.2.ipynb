# %%
secret = 4
guess = "nothing"
print(
    "There is a secret number you have to guess 1-10.. guess right you win but if you don't.... well.. you get hints... better not have more then 5 guesses or you might make me laugh.... then you have one more challenge....."
)
guesses = []

while not guess == 4:
  try:
    guess = int(input("Type Your number here"))
    if guess > 10:
      print("Your number is too big only can be 10 or lower")
      guesses.append(guess)
    elif guess < secret:
      if len(guesses) > 24:
        print("No!!")

      elif len(guesses) == 23:
        print("NOOO  its 4!!!! Pick it!!!!")
        guesses.append(guess)
      elif len(guesses) == 22:
        print(
            "OKAY IT'S NOT THIS HARD!!!! Please pick the number Heres a Helpful hint.... its more than 3 less than 5!!!!"
        )
      elif len(guesses) == 21:
        print("OMG!!! Am I gonna be here all day!!!....")
      elif len(guesses) == 20:
        print(
            "(snickers) HAHAHAHAHAHAHAHAHAHAHAHAHAHAHA Please You had a 1 in ten chance... please... (wipes laughing tears) "
        )
      elif len(guesses) >= 10:
        print(
            "(snickers) OMG Please pick the Number Please!!! AHAHAHAHAHA!!!..you probably repeated a guess.. I Might laugh to death.... (snickers)"
        )
      elif len(guesses) >= 5:
        print("HAHAHA... omg....... whats this?!?!?")

      print("higher")
      guesses.append(guess)
    elif guess > secret:
      if len(guesses) > 24:
        print("No!!")

      elif len(guesses) == 23:
        print("NOOO  its 4!!!! Pick it!!!!")
      elif len(guesses) == 22:
        print(
            "OKAY IT'S NOT THIS HARD!!!! Please pick the number Heres a Helpful hint.... its more than 3 less than 5!!!!"
        )
      elif len(guesses) == 21:
        print("OMG!!! Am I gonna be here all day!!!....")
      elif len(guesses) == 20:
        print(
            "(snickers) HAHAHAHAHAHAHAHAHAHAHAHAHAHAHA Please You had a 1 in ten chance... please... (wipes laughing tears) "
        )
      elif len(guesses) >= 10:
        print(
            "(snickers) OMG Please pick the Number Please!!! AHAHAHAHAHA!!!..you probably repeated a guess.. I Might laugh to death.... (snickers)"
        )
      elif len(guesses) >= 5:
        print("HAHAHA... omg....... whats this?!?!?")

      print("lower")
      guesses.append(guess)
    else:
      print("good job.... you guessed it right")
      guesses.append(guess)
      if len(guesses) == 1:
        print("you guessed it in on your first try good job")
      elif len(guesses) >= 20:
        print(
            f"-....Just kidding!!! What was that!? It took you {len(guesses)} guesses What is that!?"
        )
      else:
        print(f"you guessed it in {len(guesses)} guesses")
  except:
    print("That is not a whole number")
    guesses.append(guess)


print("")
print("")
print("")
print("")
print("next challege you have to solve this riddle then you get youe final challenge. Whats small and green; A cherry, pea, watermelon, or pumpkin. I know this might take a moment.. don't stress....")
pick="nill"
guessed=0
food_values={"pea":True,"cherry":False,"watermelon":False,"pumpkin":False}
while True:
  try:
    pick=food_values[input("Whats the answer my riddle:")]
    if pick==True:
      print(f"good job..... YOUR Callenge is to eat....{len(guesses)} peas after you leave")
      break
    elif pick==False:
      print("WRONG ANSWER TRY AGAIN!!")
      guessed= guessed+1
      if guessed>=5:
        print("REALLY!?!")
      
    else:
      print("Thats not an answer to the riddle!!!!!!!!")
      guessed= guessed+1
      if guessed>=5:
        print("REALLY!?!")
  except:
    print("Thats not an answer to the riddle!!!!!!!!")
    guessed= guessed+1
    if guessed>=5:
      print("REALLY!?!")
